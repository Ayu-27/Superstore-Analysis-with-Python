# %% [markdown]
# # Analysis of Superstore

# %% [markdown]
# ## 1.Extracting  Dataset (CSV file)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Analysis of Super Store.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State
# 0       Second Class   Consumer  United States        Henderson    Kentucky  \
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity
# 0         42420.0  South        Furniture    Bookcases  261.9600       2.0  \
# 1         42420.0  South        Furniture       Chairs  731.9400       3.0
# 2         90036.0   West  Office Supplies       Labels   14.6200       2.0
# 3         33311.0  South        Furniture       Tables  957.5775       5.0
# 4         33311.0  South  Office Supplies      Storage   22.3680       2.0
# ...           ...    ...              ...          ...       ...       ...
# 9990      92627.0   West        Furniture  Furnishings   91.9600       2.0
# 9991      92627.0   West       Technology       Phones  258.5760       2.0
# 9992      92627.0   West  Office Supplies        Paper   29.6000       4.0
# 9993      92683.0   West  Office Supplies   Appliances  243.1600       2.0
# 9994          NaN   West  Office Supplies        paper  243.1600       2.0
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
# 9994      0.00       NaN
#
# [9995 rows x 13 columns]

# %% [markdown]
# ## 2. Analizing Dataset

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity
# 0      42420.0  South        Furniture    Bookcases  261.9600       2.0  \
# 1      42420.0  South        Furniture       Chairs  731.9400       3.0
# 2      90036.0   West  Office Supplies       Labels   14.6200       2.0
# 3      33311.0  South        Furniture       Tables  957.5775       5.0
# 4      33311.0  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State
# 9990  Standard Class  Consumer  United States   Costa Mesa  California  \
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
# 9994    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity
# 9990      92627.0   West        Furniture  Furnishings   91.960       2.0  \
# 9991      92627.0   West       Technology       Phones  258.576       2.0
# 9992      92627.0   West  Office Supplies        Paper   29.600       4.0
# 9993      92683.0   West  Office Supplies   Appliances  243.160       2.0
# 9994          NaN   West  Office Supplies        paper  243.160       2.0
#
#       Discount   Profit
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
# 9994       0.0      NaN

# %%
df.shape
# Out:
# (9995, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9995 entries, 0 to 9994
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9995 non-null   object
#  1   Segment       9995 non-null   object
#  2   Country       9995 non-null   object
#  3   City          9995 non-null   object
#  4   State         9995 non-null   object
#  5   Postal Code   9993 non-null   float64
#  6   Region        9995 non-null   object
#  7   Category      9995 non-null   object
#  8   Sub-Category  9995 non-null   object
#  9   Sales         9995 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(5), object(8)
# memory usage: 1015.2+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     2
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        1
# Discount        1
# Profit          1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ##### 17 Duplicate rows are there

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### 1. Missing Value

# %% [markdown]
# ### 2. Remove Duplicate Value

# %% [markdown]
# ### 3. Outlier :

# %% [markdown]
# ### 4 . Scaling

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     2
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        1
# Discount        1
# Profit          1
# dtype: int64

# %%
df[['Postal Code','Quantity','Discount','Profit']]=df[['Postal Code','Quantity','Discount','Profit']].fillna(value= 0)
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### No Null Value Left

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ##  There are 17 duplicate value Hence we remove them to get accurate result

# %%
df.drop_duplicates(inplace =True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## No duplicate row left

# %% [markdown]
# ### Now remove unimportant columns

# %%
df.drop(["Country","Postal Code"], axis =1,inplace=True)

# %%
df.shape
# Out:
# (9978, 11)

# %% [markdown]
# ## Checking the correlation between the features

# %%
rel=df.select_dtypes( include=[np.number] )
rel
# Out:
#          Sales  Quantity  Discount    Profit
# 0     261.9600       2.0      0.00   41.9136
# 1     731.9400       3.0      0.00  219.5820
# 2      14.6200       2.0      0.00    6.8714
# 3     957.5775       5.0      0.45 -383.0310
# 4      22.3680       2.0      0.20    2.5164
# ...        ...       ...       ...       ...
# 9990   91.9600       2.0      0.00   15.6332
# 9991  258.5760       2.0      0.20   19.3932
# 9992   29.6000       4.0      0.00   13.3200
# 9993  243.1600       2.0      0.00   72.9480
# 9994  243.1600       2.0      0.00    0.0000
#
# [9978 rows x 4 columns]

# %%
fig,ax=plt.subplots(figsize=(12,8))
sns.heatmap(rel.corr(method='pearson'), annot=True, fmt= '.1f',ax=ax, cmap="Reds")
# Out:
# <Axes: >

# %% [markdown]
# ###  NO such strong correlation are found

# %% [markdown]
# # Outlier Detection and removal accordingly:-

# %%
plt.figure(figsize=[12,8])
sns.set(style="whitegrid")
sns.boxplot(x="variable", y="value", data=pd.melt(rel), width=1)
plt.show()

# %% [markdown]
# ### As it's a large data set, we can remove those rows containing outliers to improve our results.

# %%
#function to remove the outliers

def remove_outlier(dataset,k=3.33):
    for col in dataset.columns:
            if (dataset[col].dtype=="int64" or dataset[col].dtype=="float64"):
                mean = dataset[col].mean()
                global ds      
                std = dataset[col].std()    
                outlier = [i for i in dataset[col] if (i > mean - k * std)]
                outlier = [i for i in outlier if (i < mean + k * std)]       
                ds = dataset.loc[dataset[col].isin(outlier)]

# %%
remove_outlier(df,k=3.33) #function call

# %%
#checking whether the outliers is removed or not 
ds_con=ds.select_dtypes(include=[np.number])
plt.figure(figsize=[12,8])
sns.set(style="whitegrid")
sns.boxplot(x="variable", y="value", data=pd.melt(ds_con), width=1)

plt.show()

# %% [markdown]
# # Exploratory Analysis

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9978.000000  9978.000000  9978.000000  9978.000000
# mean     230.150205     3.790038     0.156263    28.687254
# std      623.690164     2.226908     0.206451   234.446266
# min        0.444000     0.000000     0.000000 -6599.978000
# 25%       17.302500     2.000000     0.000000     1.725150
# 50%       54.816000     3.000000     0.200000     8.666500
# 75%      209.970000     5.000000     0.200000    29.370000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ###  checking the unique values

# %%
for col in df.columns:
    if df[col].dtype=='object':
        print("Number of unique entries in",col + " are",df[col].nunique())
        print()
# Out:
# Number of unique entries in Ship Mode are 4
#
# Number of unique entries in Segment are 3
#
# Number of unique entries in City are 531
#
# Number of unique entries in State are 49
#
# Number of unique entries in Region are 4
#
# Number of unique entries in Category are 3
#
# Number of unique entries in Sub-Category are 18

# %% [markdown]
# ## Visualization to Explore and get insights=>

# %%
#Region wise sales plot
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ds['Region'],ds['Sales'])
plt.title("Region VS Sales")
plt.xlabel("Regions")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ### Observation:- The West region is leading the sales followed by the East, South and North

# %%
#Category wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Sales", hue="Category", data=ds, palette="Blues")

# %% [markdown]
# ### Observation:- In each and every every region, sales for 'Office Supplies' are very poor. Furniture and Technology are well ahead

# %%
#Category wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Sales", hue="Category", data=ds, palette="Blues")

# %% [markdown]
# ### Observation:- In each and every every region, sales for 'Office Supplies' are very poor. Furniture and Technology are well ahead.

# %%
#Segment wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Sales", hue="Segment", data=ds, palette="Blues")

# %% [markdown]
# ### Observation:- In case of sales not much difference is seen based on the Segments for any region. Overall 'Corporate' is leading a bit.

# %%
#Segment wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Profit", hue="Segment", data=ds, palette="Blues")

# %%
#Sales vs Subcategory
plt.figure(figsize=[20,10])
plt.bar("Sub-Category","Sales",data=ds)
plt.title("Sub_Category VS Sales",fontsize=18)
plt.xlabel("Subcategory", fontsize=16)
plt.ylabel("Sales",fontsize=16)
plt.show()

# %% [markdown]
# ### Observation:- As we can see, the 'Supplies' sub-category produces maximum sales followed by the 'Machines' sub-category. 'Fasteners' are lagging behind of all.

# %%
#Let's get some aggregated views from pairplot
sns.pairplot(ds)

# %% [markdown]
# ### Observation:- No such strong linear relations are found here between columns of the Dataset, irregularity is seen allover.

# %%
#Let's get some insights based on Cities
grouped= ds.groupby("City")
#Aggregated Sales per city
agg_sales=grouped['Sales'].agg(np.sum).sort_values(ascending=False).reset_index()
#Cities with highest total sales
agg_sales.head()
# Out:
#             City       Sales
# 0  New York City  197246.023
# 1    Los Angeles  164434.549
# 2  San Francisco  109777.212
# 3        Seattle   96250.488
# 4   Philadelphia   91772.849

# %% [markdown]
# ### Observation:- New York City has the most amount of sales followed by Los Angeles and San Fracisco.

# %%
#Aggregated Profit per city
agg_profit=grouped['Profit'].agg(np.sum).sort_values(ascending=False).reset_index()
#Cities with Highest total Profit
agg_profit.head()
# Out:
#             City      Profit
# 0  New York City  39934.8107
# 1    Los Angeles  26544.4140
# 2        Seattle  18916.8467
# 3  San Francisco  16521.1321
# 4        Detroit   8200.3235

# %% [markdown]
# ### Observation:- Similarly most profit is earned from New York City followed by Los Angeles and Seattle.

# %%
#Aggregate Discount per city
agg_dist=grouped['Discount'].agg(np.sum).sort_values(ascending=False).reset_index()

#Cities with highest aggregated Discount
agg_dist.head()
# Out:
#            City  Discount
# 0  Philadelphia    173.50
# 1       Houston    139.54
# 2       Chicago    117.90
# 3        Dallas     55.50
# 4   Los Angeles     54.70

# %% [markdown]
# ### Observation:- Interestingly highest total discount is for Philadelphia followed by Houston and Chicago. Shouldn't they lead the Sales and Profit table as well!

# %%
#Average Sales per city
avg_sales=grouped['Sales'].agg(np.mean).sort_values(ascending=False).reset_index()
#Cities with highest Average sales
avg_sales.head()
# Out:
#            City        Sales
# 0      Cheyenne  1603.136000
# 1    Bellingham  1263.413333
# 2  Independence  1208.685000
# 3       Burbank  1082.386000
# 4       Buffalo   906.349600

# %%
#Cities with lowest Average sales
avg_sales.tail()
#Average Profit per city
avg_profit=grouped['Profit'].agg(np.mean).sort_values(ascending=False).reset_index()
#Cities with highest Average profit
avg_profit.head()
# Out:
#            City      Profit
# 0  Independence  487.831500
# 1      Appleton  277.383150
# 2       Burbank  254.844600
# 3          Lehi  225.831300
# 4       Beverly  218.306467

# %%
#Cities with lowest Average profit
avg_profit.tail()
# Out:
#           City      Profit
# 526   Rockford -104.500709
# 527     Normal -110.023200
# 528       Yuma -116.497725
# 529     Oswego -178.709200
# 530  Champaign -182.352000

# %%
#Average Discount per city
avg_dist=grouped['Discount'].agg(np.mean).sort_values(ascending=False).reset_index()
#Cities with highest Average discount
avg_dist.head()
# Out:
#             City  Discount
# 0  Missouri City       0.8
# 1     Romeoville       0.8
# 2      Deer Park       0.8
# 3        Abilene       0.8
# 4         Elyria       0.7

# %%
#Cities with lowest Average Discount
avg_dist.tail()
# Out:
#            City  Discount
# 526     Bozeman       0.0
# 527      Mobile       0.0
# 528  Montebello       0.0
# 529  Montgomery       0.0
# 530    Aberdeen       0.0

# %% [markdown]
# ### Observation:- Something new, in all these average calculations, the Cities which topped the total Sales, total Profit or total Discount, are not leading here. But the overall scinerio can be obtained from these average values.
